# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
Data_1 = pd.read_csv('../data/train_data/01_음식물쓰레기_FOOD_WASTE_210811_update.CSV',encoding='cp949', low_memory = False)
Data_2 = pd.read_csv('../data/train_data/02-1_내국인유동인구_KOREAN.CSV',encoding='cp949')
Data_3 = pd.read_csv('../data/train_data/02-2_장기체류 외국인 유동인구_LONG_TERM_FRGN.CSV',encoding='cp949')
Data_4 = pd.read_csv('../data/train_data/02-3_단기체류 외국인 유동인구_SHORT_TERM_FRGN.CSV',encoding='cp949')
Data_5 = pd.read_csv('../data/train_data/04_음식관련 카드소비_CARD_SPENDING.CSV',encoding='cp949')

# %% [markdown]
# ## 아침, 점심, 저녁 내국인 유동인구

# %%
a = ['우도면', '추자면']
Data_2 = Data_2.drop(Data_2.query("emd_nm in @a").index)

# %%
temp = Data_2.groupby(['base_date','emd_nm','time']).sum().reset_index()
temp
# Out:
#           base_date emd_nm  time      emd_cd   age  resd_pop_cnt  \
# 0        2018-01-01    건입동     1  1803981240  1440     8234.3087
# 1        2018-01-01    건입동     2  1803981240  1440     8395.8304
# 2        2018-01-01    건입동     3  1803981240  1440     8436.3172
# 3        2018-01-01    건입동     4  1803981240  1440     8449.7851
# 4        2018-01-01    건입동     5  1703760060  1290     8438.1201
# ...             ...    ...   ...         ...   ...           ...
# 1256563  2021-06-30    효돈동    20  1804699800  1440     3403.1940
# 1256564  2021-06-30    효돈동    21  1804699800  1440     3598.4514
# 1256565  2021-06-30    효돈동    22  1804699800  1440     3793.2173
# 1256566  2021-06-30    효돈동    23  1804699800  1440     3998.1158
# 1256567  2021-06-30    효돈동    24  1804699800  1440     4939.2441
#
#          work_pop_cnt  visit_pop_cnt
# 0            506.5472      5123.2413
# 1            501.6065      5236.8215
# 2            477.0906      5190.2790
# ...

# %%
temp.drop(['emd_cd','age'],axis=1,inplace=True)

# %%
a = temp.groupby(['base_date','time']).mean().reset_index()
a['emd_nm'] = '알수없음'

# %%
a = a[['base_date','emd_nm','time','resd_pop_cnt','work_pop_cnt','visit_pop_cnt']]

# %%
df = pd.concat([temp,a])

# %%
df.sort_values(by=['base_date','emd_nm'])
# Out:
#           base_date emd_nm  time  resd_pop_cnt  work_pop_cnt  visit_pop_cnt
# 0        2018-01-01    건입동     1     8234.3087      506.5472      5123.2413
# 1        2018-01-01    건입동     2     8395.8304      501.6065      5236.8215
# 2        2018-01-01    건입동     3     8436.3172      477.0906      5190.2790
# 3        2018-01-01    건입동     4     8449.7851      451.9721      5257.0690
# 4        2018-01-01    건입동     5     8438.1201      460.2766      5436.7787
# ...             ...    ...   ...           ...           ...            ...
# 1256563  2021-06-30    효돈동    20     3403.1940      176.5715      1857.2576
# 1256564  2021-06-30    효돈동    21     3598.4514      155.6464      1776.4128
# 1256565  2021-06-30    효돈동    22     3793.2173      136.4883      1802.0158
# 1256566  2021-06-30    효돈동    23     3998.1158      121.6452      1692.6367
# 1256567  2021-06-30    효돈동    24     4939.2441       75.4621       926.5442
#
# [1287216 rows x 6 columns]

# %%
a = [7,8,9]
temp = df.query("time in @a")

# %%
temp = temp.groupby(['base_date','emd_nm']).sum().reset_index()

# %%
temp.drop('time',axis=1,inplace=True)

# %%
temp.columns = ['일자','읍면동','아침_거주인구','아침_근무인구','아침_방문인구']
base = temp
base
# Out:
#                일자  읍면동      아침_거주인구    아침_근무인구     아침_방문인구
# 0      2018-01-01  건입동   23135.2020  2197.3953  23734.9423
# 1      2018-01-01  구좌읍   34088.4096  2133.9308  39279.5331
# 2      2018-01-01  남원읍   36792.2482  2370.7174  29574.9226
# 3      2018-01-01  노형동  147677.8328  6067.6430  39108.8039
# 4      2018-01-01  대륜동   35091.6521  2239.7704  24145.2365
# ...           ...  ...          ...        ...         ...
# 53629  2021-06-30  표선면   30642.5574  2948.9168  21019.1984
# 53630  2021-06-30  한경면   21503.2446  1912.2242  11617.5659
# 53631  2021-06-30  한림읍   59846.8685  6475.3745  34625.2806
# 53632  2021-06-30  화북동   73562.6806  5919.7466  28408.3363
# 53633  2021-06-30  효돈동   10907.4568   634.1596   4465.1551
#
# [53634 rows x 5 columns]

# %%
a = [11,12,13]
temp = df.query("time in @a")

# %%
temp = temp.groupby(['base_date','emd_nm']).sum().reset_index()

# %%
temp.drop('time',axis=1,inplace=True)

# %%
temp.columns = ['일자','읍면동','점심_거주인구','점심_근무인구','점심_방문인구']
base = pd.merge(base, temp, how='left')

# %%
a = [17,18,19]
temp = df.query("time in @a")
temp = temp.groupby(['base_date','emd_nm']).sum().reset_index()
temp.drop('time',axis=1,inplace=True)
temp.columns = ['일자','읍면동','저녁_거주인구','저녁_근무인구','저녁_방문인구']
base = pd.merge(base, temp, how='left')
base
# Out:
#                일자  읍면동      아침_거주인구    아침_근무인구     아침_방문인구      점심_거주인구  \
# 0      2018-01-01  건입동   23135.2020  2197.3953  23734.9423   19103.7819
# 1      2018-01-01  구좌읍   34088.4096  2133.9308  39279.5331   32386.3979
# 2      2018-01-01  남원읍   36792.2482  2370.7174  29574.9226   33437.2235
# 3      2018-01-01  노형동  147677.8328  6067.6430  39108.8039  131213.4800
# 4      2018-01-01  대륜동   35091.6521  2239.7704  24145.2365   28965.6549
# ...           ...  ...          ...        ...         ...          ...
# 53629  2021-06-30  표선면   30642.5574  2948.9168  21019.1984   26721.8432
# 53630  2021-06-30  한경면   21503.2446  1912.2242  11617.5659   18252.7447
# 53631  2021-06-30  한림읍   59846.8685  6475.3745  34625.2806   53300.7115
# 53632  2021-06-30  화북동   73562.6806  5919.7466  28408.3363   51819.2324
# 53633  2021-06-30  효돈동   10907.4568   634.1596   4465.1551    8190.4122
#
#           점심_근무인구     점심_방문인구      저녁_거주인구     저녁_근무인구     저녁_방문인구
# ...

# %% [markdown]
# ## 아침, 점심, 저녁 외국인 유동인구

# %%
a = ['우도면', '추자면']
Data_3 = Data_3.drop(Data_3.query("emd_nm in @a").index)

# %%
temp = Data_3.groupby(['base_date','emd_nm','time']).sum().reset_index()
temp
# Out:
#           base_date emd_nm  time     emd_cd  resd_pop_cnt  work_pop_cnt  \
# 0        2018-01-01    건입동     1  701548260      194.4027       30.5056
# 1        2018-01-01    건입동     2  701548260      196.6941       22.6345
# 2        2018-01-01    건입동     3  701548260      183.3233       22.6345
# 3        2018-01-01    건입동     4  701548260      188.7795       13.3501
# 4        2018-01-01    건입동     5  701548260      188.8245        7.8735
# ...             ...    ...   ...        ...           ...           ...
# 1256563  2021-06-30    효돈동    20  601566600       47.1162        5.2404
# 1256564  2021-06-30    효돈동    21  451174950       41.8758        5.2404
# 1256565  2021-06-30    효돈동    22  451174950       40.3908        5.2404
# 1256566  2021-06-30    효돈동    23  501305500       40.3908        0.0000
# 1256567  2021-06-30    효돈동    24  501305500       52.6508        0.0000
#
#          visit_pop_cnt
# 0             156.1608
# 1             148.8606
# 2             151.8221
# ...

# %%
temp.drop('emd_cd',axis=1,inplace=True)

# %%
a = temp.groupby(['base_date','time']).mean().reset_index()
a['emd_nm'] = '알수없음'

# %%
a = a[['base_date','emd_nm','time','resd_pop_cnt','work_pop_cnt','visit_pop_cnt']]

# %%
df = pd.concat([temp,a])

# %%
df.sort_values(by=['base_date','emd_nm'])
# Out:
#           base_date emd_nm  time  resd_pop_cnt  work_pop_cnt  visit_pop_cnt
# 0        2018-01-01    건입동     1      194.4027       30.5056       156.1608
# 1        2018-01-01    건입동     2      196.6941       22.6345       148.8606
# 2        2018-01-01    건입동     3      183.3233       22.6345       151.8221
# 3        2018-01-01    건입동     4      188.7795       13.3501       147.8880
# 4        2018-01-01    건입동     5      188.8245        7.8735       147.3685
# ...             ...    ...   ...           ...           ...            ...
# 1256563  2021-06-30    효돈동    20       47.1162        5.2404        47.4853
# 1256564  2021-06-30    효돈동    21       41.8758        5.2404        30.2029
# 1256565  2021-06-30    효돈동    22       40.3908        5.2404        25.3556
# 1256566  2021-06-30    효돈동    23       40.3908        0.0000        29.8181
# 1256567  2021-06-30    효돈동    24       52.6508        0.0000        20.0184
#
# [1287216 rows x 6 columns]

# %%
a = [7,8,9]
temp = df.query("time in @a")
temp = temp.groupby(['base_date','emd_nm']).sum().reset_index()
temp.drop('time',axis=1,inplace=True)
temp.columns = ['일자','읍면동','아침_장외_거주인구','아침_장외_근무인구','아침_장외_방문인구']
base = pd.merge(base, temp, how='left')
base
# Out:
#                일자  읍면동      아침_거주인구    아침_근무인구     아침_방문인구      점심_거주인구  \
# 0      2018-01-01  건입동   23135.2020  2197.3953  23734.9423   19103.7819
# 1      2018-01-01  구좌읍   34088.4096  2133.9308  39279.5331   32386.3979
# 2      2018-01-01  남원읍   36792.2482  2370.7174  29574.9226   33437.2235
# 3      2018-01-01  노형동  147677.8328  6067.6430  39108.8039  131213.4800
# 4      2018-01-01  대륜동   35091.6521  2239.7704  24145.2365   28965.6549
# ...           ...  ...          ...        ...         ...          ...
# 53629  2021-06-30  표선면   30642.5574  2948.9168  21019.1984   26721.8432
# 53630  2021-06-30  한경면   21503.2446  1912.2242  11617.5659   18252.7447
# 53631  2021-06-30  한림읍   59846.8685  6475.3745  34625.2806   53300.7115
# 53632  2021-06-30  화북동   73562.6806  5919.7466  28408.3363   51819.2324
# 53633  2021-06-30  효돈동   10907.4568   634.1596   4465.1551    8190.4122
#
#           점심_근무인구     점심_방문인구      저녁_거주인구     저녁_근무인구     저녁_방문인구  \
# ...

# %%
a = [11,12,13]
temp = df.query("time in @a")
temp = temp.groupby(['base_date','emd_nm']).sum().reset_index()
temp.drop('time',axis=1,inplace=True)
temp.columns = ['일자','읍면동','점심_장외_거주인구','점심_장외_근무인구','점심_장외_방문인구']
base = pd.merge(base, temp, how='left')
base
# Out:
#                일자  읍면동      아침_거주인구    아침_근무인구     아침_방문인구      점심_거주인구  \
# 0      2018-01-01  건입동   23135.2020  2197.3953  23734.9423   19103.7819
# 1      2018-01-01  구좌읍   34088.4096  2133.9308  39279.5331   32386.3979
# 2      2018-01-01  남원읍   36792.2482  2370.7174  29574.9226   33437.2235
# 3      2018-01-01  노형동  147677.8328  6067.6430  39108.8039  131213.4800
# 4      2018-01-01  대륜동   35091.6521  2239.7704  24145.2365   28965.6549
# ...           ...  ...          ...        ...         ...          ...
# 53629  2021-06-30  표선면   30642.5574  2948.9168  21019.1984   26721.8432
# 53630  2021-06-30  한경면   21503.2446  1912.2242  11617.5659   18252.7447
# 53631  2021-06-30  한림읍   59846.8685  6475.3745  34625.2806   53300.7115
# 53632  2021-06-30  화북동   73562.6806  5919.7466  28408.3363   51819.2324
# 53633  2021-06-30  효돈동   10907.4568   634.1596   4465.1551    8190.4122
#
#           점심_근무인구     점심_방문인구      저녁_거주인구     저녁_근무인구     저녁_방문인구  \
# ...

# %%
a = [17,18,19]
temp = df.query("time in @a")
temp = temp.groupby(['base_date','emd_nm']).sum().reset_index()
temp.drop('time',axis=1,inplace=True)
temp.columns = ['일자','읍면동','저녁_장외_거주인구','저녁_장외_근무인구','저녁_장외_방문인구']
base = pd.merge(base, temp, how='left')
base
# Out:
#                일자  읍면동      아침_거주인구    아침_근무인구     아침_방문인구      점심_거주인구  \
# 0      2018-01-01  건입동   23135.2020  2197.3953  23734.9423   19103.7819
# 1      2018-01-01  구좌읍   34088.4096  2133.9308  39279.5331   32386.3979
# 2      2018-01-01  남원읍   36792.2482  2370.7174  29574.9226   33437.2235
# 3      2018-01-01  노형동  147677.8328  6067.6430  39108.8039  131213.4800
# 4      2018-01-01  대륜동   35091.6521  2239.7704  24145.2365   28965.6549
# ...           ...  ...          ...        ...         ...          ...
# 53629  2021-06-30  표선면   30642.5574  2948.9168  21019.1984   26721.8432
# 53630  2021-06-30  한경면   21503.2446  1912.2242  11617.5659   18252.7447
# 53631  2021-06-30  한림읍   59846.8685  6475.3745  34625.2806   53300.7115
# 53632  2021-06-30  화북동   73562.6806  5919.7466  28408.3363   51819.2324
# 53633  2021-06-30  효돈동   10907.4568   634.1596   4465.1551    8190.4122
#
#           점심_근무인구     점심_방문인구      저녁_거주인구     저녁_근무인구     저녁_방문인구  \
# ...

# %%
a = ['우도면', '추자면']
Data_4 = Data_4.drop(Data_4.query("emd_nm in @a").index)

# %%
temp = Data_4.groupby(['base_date','emd_nm','time']).sum().reset_index()
temp
# Out:
#           base_date emd_nm  time     emd_cd  visit_pop_cnt
# 0        2018-01-01    건입동     1  400884720       215.3073
# 1        2018-01-01    건입동     2  400884720       216.5271
# 2        2018-01-01    건입동     3  400884720       236.7032
# 3        2018-01-01    건입동     4  400884720       234.7976
# 4        2018-01-01    건입동     5  400884720       234.7976
# ...             ...    ...   ...        ...            ...
# 1187010  2021-06-30    화북동    21   50110600         1.8424
# 1187011  2021-06-30    화북동    22   50110600         1.8424
# 1187012  2021-06-30    화북동    23   50110600         1.8424
# 1187013  2021-06-30    화북동    24   50110600         1.8424
# 1187014  2021-06-30    효돈동    24   50130550         0.9212
#
# [1187015 rows x 5 columns]

# %%
temp.drop('emd_cd',axis=1,inplace=True)

# %%
a = temp.groupby(['base_date','time']).mean().reset_index()
a['emd_nm'] = '알수없음'

# %%
a = a[['base_date','emd_nm','time','visit_pop_cnt']]

# %%
df = pd.concat([temp,a])

# %%
df.sort_values(by=['base_date','emd_nm'])
# Out:
#           base_date emd_nm  time  visit_pop_cnt
# 0        2018-01-01    건입동     1       215.3073
# 1        2018-01-01    건입동     2       216.5271
# 2        2018-01-01    건입동     3       236.7032
# 3        2018-01-01    건입동     4       234.7976
# 4        2018-01-01    건입동     5       234.7976
# ...             ...    ...   ...            ...
# 1187010  2021-06-30    화북동    21         1.8424
# 1187011  2021-06-30    화북동    22         1.8424
# 1187012  2021-06-30    화북동    23         1.8424
# 1187013  2021-06-30    화북동    24         1.8424
# 1187014  2021-06-30    효돈동    24         0.9212
#
# [1217663 rows x 4 columns]

# %%
a = [7,8,9]
temp = df.query("time in @a")
temp = temp.groupby(['base_date','emd_nm']).sum().reset_index()
temp.drop('time',axis=1,inplace=True)
temp.columns = ['일자','읍면동','아침_단외_방문인구']
base = pd.merge(base, temp, how='left')
base
# Out:
#                일자  읍면동      아침_거주인구    아침_근무인구     아침_방문인구      점심_거주인구  \
# 0      2018-01-01  건입동   23135.2020  2197.3953  23734.9423   19103.7819
# 1      2018-01-01  구좌읍   34088.4096  2133.9308  39279.5331   32386.3979
# 2      2018-01-01  남원읍   36792.2482  2370.7174  29574.9226   33437.2235
# 3      2018-01-01  노형동  147677.8328  6067.6430  39108.8039  131213.4800
# 4      2018-01-01  대륜동   35091.6521  2239.7704  24145.2365   28965.6549
# ...           ...  ...          ...        ...         ...          ...
# 53629  2021-06-30  표선면   30642.5574  2948.9168  21019.1984   26721.8432
# 53630  2021-06-30  한경면   21503.2446  1912.2242  11617.5659   18252.7447
# 53631  2021-06-30  한림읍   59846.8685  6475.3745  34625.2806   53300.7115
# 53632  2021-06-30  화북동   73562.6806  5919.7466  28408.3363   51819.2324
# 53633  2021-06-30  효돈동   10907.4568   634.1596   4465.1551    8190.4122
#
#           점심_근무인구     점심_방문인구      저녁_거주인구     저녁_근무인구  ...  아침_장외_거주인구  \
# ...

# %%
a = [11,12,13]
temp = df.query("time in @a")
temp = temp.groupby(['base_date','emd_nm']).sum().reset_index()
temp.drop('time',axis=1,inplace=True)
temp.columns = ['일자','읍면동','점심_단외_방문인구']
base = pd.merge(base, temp, how='left')
base
# Out:
#                일자  읍면동      아침_거주인구    아침_근무인구     아침_방문인구      점심_거주인구  \
# 0      2018-01-01  건입동   23135.2020  2197.3953  23734.9423   19103.7819
# 1      2018-01-01  구좌읍   34088.4096  2133.9308  39279.5331   32386.3979
# 2      2018-01-01  남원읍   36792.2482  2370.7174  29574.9226   33437.2235
# 3      2018-01-01  노형동  147677.8328  6067.6430  39108.8039  131213.4800
# 4      2018-01-01  대륜동   35091.6521  2239.7704  24145.2365   28965.6549
# ...           ...  ...          ...        ...         ...          ...
# 53629  2021-06-30  표선면   30642.5574  2948.9168  21019.1984   26721.8432
# 53630  2021-06-30  한경면   21503.2446  1912.2242  11617.5659   18252.7447
# 53631  2021-06-30  한림읍   59846.8685  6475.3745  34625.2806   53300.7115
# 53632  2021-06-30  화북동   73562.6806  5919.7466  28408.3363   51819.2324
# 53633  2021-06-30  효돈동   10907.4568   634.1596   4465.1551    8190.4122
#
#           점심_근무인구     점심_방문인구      저녁_거주인구     저녁_근무인구  ...  아침_장외_근무인구  \
# ...

# %%
a = [17,18,19]
temp = df.query("time in @a")
temp = temp.groupby(['base_date','emd_nm']).sum().reset_index()
temp.drop('time',axis=1,inplace=True)
temp.columns = ['일자','읍면동','저녁_단외_방문인구']
base = pd.merge(base, temp, how='left')
base
# Out:
#                일자  읍면동      아침_거주인구    아침_근무인구     아침_방문인구      점심_거주인구  \
# 0      2018-01-01  건입동   23135.2020  2197.3953  23734.9423   19103.7819
# 1      2018-01-01  구좌읍   34088.4096  2133.9308  39279.5331   32386.3979
# 2      2018-01-01  남원읍   36792.2482  2370.7174  29574.9226   33437.2235
# 3      2018-01-01  노형동  147677.8328  6067.6430  39108.8039  131213.4800
# 4      2018-01-01  대륜동   35091.6521  2239.7704  24145.2365   28965.6549
# ...           ...  ...          ...        ...         ...          ...
# 53629  2021-06-30  표선면   30642.5574  2948.9168  21019.1984   26721.8432
# 53630  2021-06-30  한경면   21503.2446  1912.2242  11617.5659   18252.7447
# 53631  2021-06-30  한림읍   59846.8685  6475.3745  34625.2806   53300.7115
# 53632  2021-06-30  화북동   73562.6806  5919.7466  28408.3363   51819.2324
# 53633  2021-06-30  효돈동   10907.4568   634.1596   4465.1551    8190.4122
#
#           점심_근무인구     점심_방문인구      저녁_거주인구     저녁_근무인구  ...  아침_장외_방문인구  \
# ...

# %% [markdown]
# ## 노인 거주 인구

# %%
a = ['우도면', '추자면']
Data_2 = Data_2.drop(Data_2.query("emd_nm in @a").index)

# %%
temp = Data_2.groupby(['base_date','emd_nm','age']).sum().reset_index()
temp
# Out:
#          base_date emd_nm  age  time      emd_cd  resd_pop_cnt  work_pop_cnt  \
# 0       2018-01-01    건입동    0  1200  4810616640    16351.2905      713.8630
# 1       2018-01-01    건입동   10  1200  4810616640    18486.9641      814.5841
# 2       2018-01-01    건입동   20  1200  4810616640    15567.3243     3324.0660
# 3       2018-01-01    건입동   30  1200  4810616640    21464.1979     3076.2479
# 4       2018-01-01    건입동   40  1200  4810616640    28162.6876     4193.0287
# ...            ...    ...  ...   ...         ...           ...           ...
# 471208  2021-06-30    효돈동   40  1200  4812532800    13048.2698     1201.3172
# 471209  2021-06-30    효돈동   50  1200  4812532800    15587.7237     1371.6294
# 471210  2021-06-30    효돈동   60  1200  4812532800    13604.6820      695.3218
# 471211  2021-06-30    효돈동   70  1200  4812532800     9921.4180      176.8777
# 471212  2021-06-30    효돈동   80  1200  4812532800     5891.2591       82.1290
#
#         visit_pop_cnt
# ...

# %%
temp.drop(['time','emd_cd','work_pop_cnt','visit_pop_cnt'],axis=1,inplace=True)

# %%
a = Data_2.groupby(['base_date','age']).mean().reset_index()
a
# Out:
#         base_date  age      time        emd_cd  resd_pop_cnt  work_pop_cnt  \
# 0      2018-01-01    0  12.50000  5.011880e+07    328.861353     17.397306
# 1      2018-01-01   10  12.50000  5.011880e+07    377.867026     19.829098
# 2      2018-01-01   20  12.50000  5.011880e+07    298.212379     33.702832
# 3      2018-01-01   30  12.50000  5.011880e+07    398.136245     32.299138
# 4      2018-01-01   40  12.50000  5.011880e+07    585.651856     43.497336
# ...           ...  ...       ...           ...           ...           ...
# 11488  2021-06-30   40  12.50000  5.011880e+07    553.481824     77.992414
# 11489  2021-06-30   50  12.50000  5.011880e+07    571.148903     73.007198
# 11490  2021-06-30   60  12.50000  5.011880e+07    409.319619     31.457252
# 11491  2021-06-30   70  12.50687  5.011882e+07    222.679970      9.381148
# 11492  2021-06-30   80  12.50687  5.011882e+07    107.505247      4.580606
#
#        visit_pop_cnt
# 0         201.988818
# 1         231.953506
# ...

# %%
a.drop(['time','emd_cd','work_pop_cnt','visit_pop_cnt'],axis=1,inplace=True)

# %%
a['emd_nm'] = '알수없음'

# %%
a = a[['base_date','emd_nm','age','resd_pop_cnt']]

# %%
temp = pd.concat([temp,a])
temp
# Out:
#         base_date emd_nm  age  resd_pop_cnt
# 0      2018-01-01    건입동    0  16351.290500
# 1      2018-01-01    건입동   10  18486.964100
# 2      2018-01-01    건입동   20  15567.324300
# 3      2018-01-01    건입동   30  21464.197900
# 4      2018-01-01    건입동   40  28162.687600
# ...           ...    ...  ...           ...
# 11488  2021-06-30   알수없음   40    553.481824
# 11489  2021-06-30   알수없음   50    571.148903
# 11490  2021-06-30   알수없음   60    409.319619
# 11491  2021-06-30   알수없음   70    222.679970
# 11492  2021-06-30   알수없음   80    107.505247
#
# [482706 rows x 4 columns]

# %%
temp.sort_values(by=['base_date','emd_nm'])
# Out:
#          base_date emd_nm  age  resd_pop_cnt
# 0       2018-01-01    건입동    0    16351.2905
# 1       2018-01-01    건입동   10    18486.9641
# 2       2018-01-01    건입동   20    15567.3243
# 3       2018-01-01    건입동   30    21464.1979
# 4       2018-01-01    건입동   40    28162.6876
# ...            ...    ...  ...           ...
# 471208  2021-06-30    효돈동   40    13048.2698
# 471209  2021-06-30    효돈동   50    15587.7237
# 471210  2021-06-30    효돈동   60    13604.6820
# 471211  2021-06-30    효돈동   70     9921.4180
# 471212  2021-06-30    효돈동   80     5891.2591
#
# [482706 rows x 4 columns]

# %%
temp = temp[temp['age']>50]

# %%
temp = temp.groupby(['base_date','emd_nm']).sum().reset_index()
temp.drop('age',axis=1,inplace=True)
temp
# Out:
#         base_date emd_nm  resd_pop_cnt
# 0      2018-01-01    건입동    40177.1069
# 1      2018-01-01    구좌읍    68359.4896
# 2      2018-01-01    남원읍    73921.0157
# 3      2018-01-01    노형동   157041.0816
# 4      2018-01-01    대륜동    52420.4092
# ...           ...    ...           ...
# 53629  2021-06-30    표선면    73414.5437
# 53630  2021-06-30    한경면    58798.7886
# 53631  2021-06-30    한림읍   130420.4945
# 53632  2021-06-30    화북동   100418.3094
# 53633  2021-06-30    효돈동    29417.3591
#
# [53634 rows x 3 columns]

# %%
temp.columns = ['일자','읍면동','노인거주인구']

# %%
base = pd.merge(base, temp, how='left')
base
# Out:
#                일자  읍면동      아침_거주인구    아침_근무인구     아침_방문인구      점심_거주인구  \
# 0      2018-01-01  건입동   23135.2020  2197.3953  23734.9423   19103.7819
# 1      2018-01-01  구좌읍   34088.4096  2133.9308  39279.5331   32386.3979
# 2      2018-01-01  남원읍   36792.2482  2370.7174  29574.9226   33437.2235
# 3      2018-01-01  노형동  147677.8328  6067.6430  39108.8039  131213.4800
# 4      2018-01-01  대륜동   35091.6521  2239.7704  24145.2365   28965.6549
# ...           ...  ...          ...        ...         ...          ...
# 53629  2021-06-30  표선면   30642.5574  2948.9168  21019.1984   26721.8432
# 53630  2021-06-30  한경면   21503.2446  1912.2242  11617.5659   18252.7447
# 53631  2021-06-30  한림읍   59846.8685  6475.3745  34625.2806   53300.7115
# 53632  2021-06-30  화북동   73562.6806  5919.7466  28408.3363   51819.2324
# 53633  2021-06-30  효돈동   10907.4568   634.1596   4465.1551    8190.4122
#
#           점심_근무인구     점심_방문인구      저녁_거주인구     저녁_근무인구  ...  점심_장외_거주인구  \
# ...

# %%
base.fillna(0,inplace=True)

# %% [markdown]
# ## 회 당 배출량

# %%
Data_1['em_mean'] = Data_1['em_g']/Data_1['em_cnt']
Data_1['pay_mean'] = Data_1['pay_amt']/Data_1['em_cnt']

# %%
temp = Data_1.groupby(['base_date','emd_nm']).sum().reset_index()
temp.drop(['em_cnt','em_g','pay_amt'],axis=1,inplace=True)
temp
# Out:
#         base_date emd_nm        em_mean      pay_mean
# 0      2018-01-01    건입동   71922.531403   2150.727168
# 1      2018-01-01    남원읍  191915.143697   5746.347536
# 2      2018-01-01    노형동  368469.366520  10971.836007
# 3      2018-01-01    대륜동   69681.711185   2043.970788
# 4      2018-01-01    대정읍  112840.030709   3378.265905
# ...           ...    ...            ...           ...
# 50517  2021-06-30    표선면  126786.198510   3795.708919
# 50518  2021-06-30    한경면  225253.612082   6742.826310
# 50519  2021-06-30    한림읍  496739.570517  14878.970758
# 50520  2021-06-30    화북동  139053.552499   4154.358788
# 50521  2021-06-30    효돈동   39037.062439   1168.315071
#
# [50522 rows x 4 columns]

# %%
temp.columns = ['일자','읍면동','회당배출량','회당배출금액']

# %%
base = pd.merge(base, temp, how='left')
base
# Out:
#                일자  읍면동      아침_거주인구    아침_근무인구     아침_방문인구      점심_거주인구  \
# 0      2018-01-01  건입동   23135.2020  2197.3953  23734.9423   19103.7819
# 1      2018-01-01  구좌읍   34088.4096  2133.9308  39279.5331   32386.3979
# 2      2018-01-01  남원읍   36792.2482  2370.7174  29574.9226   33437.2235
# 3      2018-01-01  노형동  147677.8328  6067.6430  39108.8039  131213.4800
# 4      2018-01-01  대륜동   35091.6521  2239.7704  24145.2365   28965.6549
# ...           ...  ...          ...        ...         ...          ...
# 53629  2021-06-30  표선면   30642.5574  2948.9168  21019.1984   26721.8432
# 53630  2021-06-30  한경면   21503.2446  1912.2242  11617.5659   18252.7447
# 53631  2021-06-30  한림읍   59846.8685  6475.3745  34625.2806   53300.7115
# 53632  2021-06-30  화북동   73562.6806  5919.7466  28408.3363   51819.2324
# 53633  2021-06-30  효돈동   10907.4568   634.1596   4465.1551    8190.4122
#
#           점심_근무인구     점심_방문인구      저녁_거주인구     저녁_근무인구  ...  점심_장외_방문인구  \
# ...

# %% [markdown]
# ## 회 당 결제금액

# %%
Data_5['use_mean'] = Data_5['use_amt']/Data_5['use_cnt']

# %%
a = ['우도면', '추자면']
Data_5 = Data_5.drop(Data_5.query("emd_nm in @a").index)

# %%
temp = Data_5.groupby(['base_date','emd_nm']).sum().reset_index()

# %%
temp.drop(['use_cnt','use_amt'],axis=1,inplace=True)

# %%
temp.columns = ['일자','읍면동','회당결제금액']

# %%
base = pd.merge(base, temp, how='left')
base
# Out:
#                일자  읍면동      아침_거주인구    아침_근무인구     아침_방문인구      점심_거주인구  \
# 0      2018-01-01  건입동   23135.2020  2197.3953  23734.9423   19103.7819
# 1      2018-01-01  구좌읍   34088.4096  2133.9308  39279.5331   32386.3979
# 2      2018-01-01  남원읍   36792.2482  2370.7174  29574.9226   33437.2235
# 3      2018-01-01  노형동  147677.8328  6067.6430  39108.8039  131213.4800
# 4      2018-01-01  대륜동   35091.6521  2239.7704  24145.2365   28965.6549
# ...           ...  ...          ...        ...         ...          ...
# 53629  2021-06-30  표선면   30642.5574  2948.9168  21019.1984   26721.8432
# 53630  2021-06-30  한경면   21503.2446  1912.2242  11617.5659   18252.7447
# 53631  2021-06-30  한림읍   59846.8685  6475.3745  34625.2806   53300.7115
# 53632  2021-06-30  화북동   73562.6806  5919.7466  28408.3363   51819.2324
# 53633  2021-06-30  효돈동   10907.4568   634.1596   4465.1551    8190.4122
#
#           점심_근무인구     점심_방문인구      저녁_거주인구     저녁_근무인구  ...  저녁_장외_거주인구  \
# ...

# %%
base.to_csv('../data/processed_data/new_feature.csv',encoding='cp949',index=False)
